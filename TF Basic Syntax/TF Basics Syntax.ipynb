# %% [markdown]
# # TensorFlow Basics
# ____
#
# Importing libraries and reading csv file:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fake_reg.csv')

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %% [markdown]
# Exploring the dataset using a pairplot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## Preparing train and test sets

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **We have to pass in numpy arrays instead of Panda's data frame, by adding .values to the end of series or data frame and it'll return it back as numpy array**

# %%
X = df[['feature1', 'feature2']].values

# %%
y = df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Normalize and scale features to avoid any network training issues

# %%
from sklearn.preprocessing import MinMaxScaler
# help(MinMaxScaler)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating and training a model
# ____
#
# Importing Sequential model and Dense from tensorflow.kears

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#help(Sequential)
#help(Dense)

# %% [markdown]
# Building normal feed forward network

# %%
# The first way to build a model
model = Sequential([Dense(4, activation='relu'),
                    Dense(2, activation='relu'),
                    Dense(1)])

# %%
# The second way to build a model
# More convenient way, due to quick editing of layers
model = Sequential()

model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(2, activation='relu'))

# last layer will be just one final output node, because we trying to predict price.
model.add(Dense(1))

# Compiling a model
model.compile(optimizer='rmsprop',loss='mse')

# %% [markdown]
# Training the model

# %%
 model.fit(x=X_train, y=y_train, epochs=250, verbose=1)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 0s 589us/step - loss: 255528.9531
# Epoch 2/250
# 22/22 [==============================] - 0s 544us/step - loss: 255234.0312
# Epoch 3/250
# 22/22 [==============================] - 0s 589us/step - loss: 254944.0625
# Epoch 4/250
# 22/22 [==============================] - 0s 589us/step - loss: 254633.7188
# Epoch 5/250
# 22/22 [==============================] - 0s 589us/step - loss: 254298.6719
# Epoch 6/250
# 22/22 [==============================] - 0s 635us/step - loss: 253941.4844
# Epoch 7/250
# 22/22 [==============================] - 0s 544us/step - loss: 253559.1562
# Epoch 8/250
# 22/22 [==============================] - 0s 543us/step - loss: 253148.9531
# Epoch 9/250
# 22/22 [==============================] - 0s 634us/step - loss: 252710.0156
# Epoch 10/250
# 22/22 [==============================] - 0s 635us/step - loss: 252246.7500
# Epoch 11/250
# 22/22 [==============================] - 0s 725us/step - loss: 251752.8281
# Epoch 12/250
# 22/22 [==============================] - 0s 621us/step - loss: 251225.9375
# Epoch 13/250
# 22/22 [==============================] - 0s 635us/step - loss: 250666.1250
# Epoch 14/250
# 22/22 [==============================] - 0s 680us/step - loss: 250075.0469
# Epoch 15/250
# 22/22 [==============================] - 0s 680us/step - loss: 249453.6250
# Epoch 16/250
# 22/22 [==============================] - 0s 635us/step - loss: 248790.3594
# Epoch 17/250
# 22/22 [==============================] - 0s 635us/step - loss: 248093.2969
# Epoch 18/250
# 22/22 [==============================] - 0s 680us/step - loss: 247358.3281
# Epoch 19/250
# 22/22 [==============================] - 0s 680us/step - loss: 246581.2969
# Epoch 20/250
# 22/22 [==============================] - 0s 589us/step - loss: 245772.8750
# Epoch 21/250
# 22/22 [==============================] - 0s 635us/step - loss: 244916.1875
# Epoch 22/250
# 22/22 [==============================] - 0s 634us/step - loss: 244014.1562
# Epoch 23/250
# 22/22 [==============================] - 0s 636us/step - loss: 243072.0469
# Epoch 24/250
# 22/22 [==============================] - 0s 635us/step - loss: 242085.2969
# 22/22 [==============================] - 0s 544us/step - loss: 27.0919
# Epoch 245/250
# 22/22 [==============================] - 0s 589us/step - loss: 26.5230
# Epoch 246/250
# 22/22 [==============================] - 0s 634us/step - loss: 26.1183
# Epoch 247/250
# 22/22 [==============================] - 0s 589us/step - loss: 26.1076
# Epoch 248/250
# 22/22 [==============================] - 0s 635us/step - loss: 25.6996
# Epoch 249/250
# 22/22 [==============================] - 0s 591us/step - loss: 25.5595
# Epoch 250/250
# 22/22 [==============================] - 0s 725us/step - loss: 25.0317

# %% [markdown]
# Check for changes in loss

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
sns.lineplot(x=range(len(loss_df['loss'])),y=loss_df['loss'])
plt.title('Training Loss per Epoch')
plt.show()

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 26.079450607299805

# %%
model.evaluate(X_train, y_train, verbose=0)
# Out:
# 24.880456924438477

# %% [markdown]
# Prediction

# %%
test_predictions = model.predict(X_test)

# %%
test_predictions
# Out:
# array([[406.4222 ],
#        [622.6082 ],
#        [591.28406],
#        [572.2672 ],
#        [369.04675],
#        [578.8066 ],
#        [516.0533 ],
#        [459.36554],
#        [549.4869 ],
#        [447.8135 ],
#        [610.9427 ],
#        [547.7967 ],
#        [420.17255],
#        [410.18613],
#        [649.0777 ],
#        [437.8669 ],
#        [507.83844],
#        [659.45276],
#        [661.6249 ],
#        [564.7839 ],
#        [336.51096],
#        [445.6502 ],
#        [384.22733],
#        [380.097  ],
#        [566.26807],
#        [610.2717 ],
#        [532.4601 ],
#        [428.69177],
#        [654.76306],
#        [414.76602],
#        [443.05695],
#        [485.50223],
#        [439.16418],
#        [680.7888 ],
#        [425.0984 ],
#        [419.09576],
#        [501.15097],
#        [550.1586 ],
#        [510.59686],
#        [397.469  ],
#        [617.50226],
#        [417.3821 ],
#        [603.52856],
#        [446.04858],
#        [502.22507],
#        [580.16656],
#        [666.8918 ],
#        [490.3681 ],
#        [320.10922],
#        [485.89133],
#        [517.1893 ],
#        [382.7096 ],
#        [541.0571 ],
#        [409.6647 ],
#        [640.1767 ],
#        [491.5672 ],
#        [627.6993 ],
#        [625.25085],
#        [447.7517 ],
#        [485.53717],
#        [491.80246],
#        [474.77118],
#        [681.1381 ],
#        [404.75208],
#        [699.4139 ],
#        [586.07587],
#        [582.4773 ],
#        [537.35547],
#        [485.00555],
#        [517.08417],
#        [362.66772],
#        [540.61536],
#        [570.42957],
#        [527.5085 ],
#        [454.23526],
#        [530.832  ],
#        [506.83337],
#        [444.61462],
#        [543.3722 ],
#        [639.05084],
#        [467.44083],
#        [566.63806],
#        [688.5785 ],
#        [459.66174],
#        [707.70184],
#        [473.27914],
#        [403.76492],
#        [584.61676],
#        [436.87665],
#        [488.96683],
#        [615.9944 ],
#        [439.85397],
#        [456.49167],
#        [436.27893],
#        [507.63977],
#        [607.89655],
#        [323.62463],
#        [436.88895],
#        [536.02057],
#        [519.1146 ],
#        [604.8908 ],
#        [525.62036],
#        [335.4402 ],
#        [575.0364 ],
#        [433.6439 ],
#        [561.2449 ],
#        [513.41986],
#        [392.6481 ],
#        [566.74713],
#        [454.6244 ],
#        [449.4993 ],
#        [639.79486],
#        [523.895  ],
#        [550.0099 ],
#        [418.7572 ],
#        [479.35516],
#        [585.9403 ],
#        [666.4373 ],
#        [699.1806 ],
#        [659.04083],
#        [560.2459 ],
#        [502.96396],
#        [392.2393 ],
#        [283.9182 ],
#        [479.83572],
#        [614.9059 ],
#        [374.1213 ],
#        [512.35   ],
#        [511.87354],
#        [494.14578],
#        [480.84705],
#        [425.38324],
#        [493.95667],
#        [471.9019 ],
#        [599.07227],
#        [572.23694],
#        [416.81607],
#        [629.5102 ],
#        [466.6144 ],
#        [563.5927 ],
#        [406.8842 ],
#        [532.2011 ],
#        [572.27356],
#        [358.997  ],
#        [549.86304],
#        [602.6712 ],
#        [385.84256],
#        [542.67834],
#        [562.2041 ],
#        [453.11267],
#        [631.1334 ],
#        [374.39322],
#        [475.1738 ],
#        [529.43036],
#        [373.47665],
#        [462.3187 ],
#        [437.63443],
#        [498.8393 ],
#        [347.25714],
#        [396.15826],
#        [603.59436],
#        [506.62704],
#        [469.28815],
#        [490.33163],
#        [534.5106 ],
#        [346.39572],
#        [511.3354 ],
#        [253.14226],
#        [504.27136],
#        [541.742  ],
#        [489.85434],
#        [470.67184],
#        [393.7244 ],
#        [416.4774 ],
#        [549.58545],
#        [476.79858],
#        [579.9135 ],
#        [490.70712],
#        [601.0711 ],
#        [546.39777],
#        [541.51965],
#        [500.75494],
#        [644.9083 ],
#        [560.2506 ],
#        [576.56213],
#        [444.18015],
#        [416.01837],
#        [421.60696],
#        [568.26166],
#        [608.5052 ],
#        [438.1824 ],
#        [488.11505],
#        [587.7569 ],
#        [525.8176 ],
#        [359.1447 ],
#        [644.60114],
#        [528.4008 ],
#        [338.9903 ],
#        [493.077  ],
#        [410.68243],
#        [605.6928 ],
#        [347.65552],
#        [521.9082 ],
#        [405.54974],
#        [261.89026],
#        [519.6016 ],
#        [341.7238 ],
#        [364.25174],
#        [575.3198 ],
#        [417.11868],
#        [551.07086],
#        [521.418  ],
#        [512.1826 ],
#        [326.4494 ],
#        [406.05444],
#        [602.16956],
#        [617.39703],
#        [603.5531 ],
#        [565.23517],
#        [474.43246],
#        [460.91013],
#        [508.72043],
#        [446.24536],
#        [510.78397],
#        [503.41132],
#        [401.0265 ],
#        [604.83514],
#        [260.81088],
#        [627.0434 ],
#        [587.4879 ],
#        [328.57202],
#        [480.49838],
#        [594.5176 ],
#        [379.64722],
#        [460.85352],
#        [326.38327],
#        [518.2414 ],
#        [410.00693],
#        [555.7186 ],
#        [640.54974],
#        [536.8498 ],
#        [503.06662],
#        [633.50586],
#        [515.0386 ],
#        [531.66565],
#        [519.3614 ],
#        [457.92255],
#        [505.49182],
#        [461.4925 ],
#        [590.2686 ],
#        [466.6904 ],
#        [428.5512 ],
#        [541.96136],
#        [494.2471 ],
#        [679.4545 ],
#        [374.28082],
#        [551.33093],
#        [577.42053],
#        [435.2993 ],
#        [543.14777],
#        [584.771  ],
#        [578.1694 ],
#        [719.20496],
#        [434.39896],
#        [399.48883],
#        [315.70413],
#        [449.3216 ],
#        [388.59332],
#        [543.42896],
#        [522.9311 ],
#        [563.2752 ],
#        [448.70657],
#        [534.0895 ],
#        [382.99435],
#        [501.61636],
#        [636.47644],
#        [496.07687],
#        [568.3294 ],
#        [470.9874 ],
#        [274.7311 ],
#        [517.8287 ],
#        [620.68524],
#        [352.18793],
#        [451.84457],
#        [499.90283],
#        [542.8624 ],
#        [610.63666],
#        [390.24042],
#        [450.90036],
#        [482.60516],
#        [597.87683],
#        [500.32562],
#        [323.3657 ],
#        [554.91815],
#        [445.34   ],
#        [529.4231 ],
#        [516.9448 ],
#        [608.746  ],
#        [417.5392 ],
#        [412.31235]], dtype=float32)

# %% [markdown]
# Comparing predicted and true values

# %%
test_predictions = pd.Series(test_predictions.reshape(300,))
pred_df = pd.DataFrame(y_test, columns=['Test True Y'])

# %%
pred_df = pd.concat([pred_df, test_predictions], axis=1)

# %%
pred_df.columns = ['Test True Y', 'Model Predictions']

# %%
pred_df
# Out:
#      Test True Y  Model Predictions
# 0     402.296319         406.422211
# 1     624.156198         622.608215
# 2     582.455066         591.284058
# 3     578.588606         572.267212
# 4     371.224104         369.046753
# ..           ...                ...
# 295   525.704657         529.423096
# 296   502.909473         516.944824
# 297   612.727910         608.745972
# 298   417.569725         417.539215
# 299   410.538250         412.312347
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(x='Test True Y', y='Model Predictions', data=pred_df)
plt.show()

# %% [markdown]
# Checking the prediction error

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 4.142619435653111

# %%
df.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308

# %% [markdown]
# The mean absolute error is less then 1%m which means that model is preforming very well!

# %%
mean_squared_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 26.07945511269839

# %%
#Root mean squared error
np.sqrt(mean_squared_error(pred_df['Test True Y'], pred_df['Model Predictions']))
# Out:
# 5.106804785058696

# %% [markdown]
# ## Predicting on the brand new data
# ____

# %%
new_gem = [[998, 1000]]

# %%
new_gem = scaler.transform(new_gem)

# %%
model.predict(new_gem)
# Out:
# array([[421.5491]], dtype=float32)

# %% [markdown]
# ## Saving model
# ____

# %%
from tensorflow.keras.models import load_model

# %%
model.save('my_gem_model.h5')

# %%
later_model = load_model('my_gem_model.h5')

# %%
later_model.predict(new_gem)
# Out:
# array([[421.5491]], dtype=float32)

# %% [markdown]
# A loaded model predicts the same result as the original model.
# ____
